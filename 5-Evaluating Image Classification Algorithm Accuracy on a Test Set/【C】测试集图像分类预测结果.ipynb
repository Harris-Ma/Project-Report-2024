# %% [markdown]
# # 测试集图像分类预测结果
#
# 使用训练好的图像分类模型，预测测试集的所有图像，得到预测结果表格。

# %% [markdown]
# ## 导入工具包

# %%
import os
from tqdm import tqdm

import numpy as np
import pandas as pd

from PIL import Image

import torch
import torch.nn.functional as F

# 有 GPU 就用 GPU，没有就用 CPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('device', device)
# Out:
# device cuda:0

# %% [markdown]
# ## 图像预处理

# %%
from torchvision import transforms

# # 训练集图像预处理：缩放裁剪、图像增强、转 Tensor、归一化
# train_transform = transforms.Compose([transforms.RandomResizedCrop(224),
#                                       transforms.RandomHorizontalFlip(),
#                                       transforms.ToTensor(),
#                                       transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
#                                      ])

# 测试集图像预处理-RCTN：缩放、裁剪、转 Tensor、归一化
test_transform = transforms.Compose([transforms.Resize(256),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize(
                                         mean=[0.485, 0.456, 0.406], 
                                         std=[0.229, 0.224, 0.225])
                                    ])

# %% [markdown]
# ## 载入测试集（和训练代码教程相同）

# %%
# 数据集文件夹路径
dataset_dir = 'Particle Figures_split'
test_path = os.path.join(dataset_dir, 'val')
from torchvision import datasets
# 载入测试集
test_dataset = datasets.ImageFolder(test_path, test_transform)
print('测试集图像数量', len(test_dataset))
print('类别个数', len(test_dataset.classes))
print('各类别名称', test_dataset.classes)
# 载入类别名称 和 ID索引号 的映射字典
idx_to_labels = np.load('idx_to_labels.npy', allow_pickle=True).item()
# 获得类别名称
classes = list(idx_to_labels.values())
print(classes)
# Out:
# 测试集图像数量 248
# 类别个数 6
# 各类别名称 ['Angular', 'Rounded', 'Subangular', 'Subrounded', 'Very angular', 'Well rounded']
# ['Angular', 'Rounded', 'Subangular', 'Subrounded', 'Very angular', 'Well rounded']

# %% [markdown]
# ## 导入训练好的模型

# %%
model = torch.load('Particle Figures_pytorch_C1.pth')
model = model.eval().to(device)

# %% [markdown]
# ## 表格A-测试集图像路径及标注

# %%
test_dataset.imgs[:10]
# Out:
# [('Particle Figures_split/val/Angular/Angular (10).jpg', 0),
#  ('Particle Figures_split/val/Angular/Angular (106).jpg', 0),
#  ('Particle Figures_split/val/Angular/Angular (111).jpg', 0),
#  ('Particle Figures_split/val/Angular/Angular (13).jpg', 0),
#  ('Particle Figures_split/val/Angular/Angular (130).jpg', 0),
#  ('Particle Figures_split/val/Angular/Angular (131).jpg', 0),
#  ('Particle Figures_split/val/Angular/Angular (133).jpg', 0),
#  ('Particle Figures_split/val/Angular/Angular (143).jpg', 0),
#  ('Particle Figures_split/val/Angular/Angular (146).jpg', 0),
#  ('Particle Figures_split/val/Angular/Angular (149).jpg', 0)]

# %%
img_paths = [each[0] for each in test_dataset.imgs]

# %%
df = pd.DataFrame()
df['Image path'] = img_paths
df['Labeling categories ID'] = test_dataset.targets
df['Labeling categories name'] = [idx_to_labels[ID] for ID in test_dataset.targets]

# %%
df
# Out:
#                                             Image path  \
# 0    Particle Figures_split/val/Angular/Angular (10...
# 1    Particle Figures_split/val/Angular/Angular (10...
# 2    Particle Figures_split/val/Angular/Angular (11...
# 3    Particle Figures_split/val/Angular/Angular (13...
# 4    Particle Figures_split/val/Angular/Angular (13...
# ..                                                 ...
# 243  Particle Figures_split/val/Well rounded/Well r...
# 244  Particle Figures_split/val/Well rounded/Well r...
# 245  Particle Figures_split/val/Well rounded/Well r...
# 246  Particle Figures_split/val/Well rounded/Well r...
# 247  Particle Figures_split/val/Well rounded/Well r...
#
#      Labeling categories ID Labeling categories name
# 0                         0                  Angular
# 1                         0                  Angular
# 2                         0                  Angular
# 3                         0                  Angular
# 4                         0                  Angular
# ..                      ...                      ...
# 243                       5             Well rounded
# 244                       5             Well rounded
# 245                       5             Well rounded
# 246                       5             Well rounded
# 247                       5             Well rounded
#
# [248 rows x 3 columns]

# %% [markdown]
# ## 表格B-测试集每张图像的图像分类预测结果，以及各类别置信度

# %%
# 记录 top-n 预测结果
n = 3

# %%
df_pred = pd.DataFrame()
for idx, row in tqdm(df.iterrows()):
    img_path = row['Image path']
    img_pil = Image.open(img_path).convert('RGB')
    input_img = test_transform(img_pil).unsqueeze(0).to(device) # 预处理
    pred_logits = model(input_img) # 执行前向预测，得到所有类别的 logit 预测分数
    pred_softmax = F.softmax(pred_logits, dim=1) # 对 logit 分数做 softmax 运算

    pred_dict = {}

    top_n = torch.topk(pred_softmax, n) # 取置信度最大的 n 个结果
    pred_ids = top_n[1].cpu().detach().numpy().squeeze() # 解析出类别
    
    # top-n 预测结果
    for i in range(1, n+1):
        pred_dict['top-{}-Predictions ID'.format(i)] = pred_ids[i-1]
        pred_dict['top-{}-Predictions name'.format(i)] = idx_to_labels[pred_ids[i-1]]
    pred_dict['top-n Predictions correction'] = row['Labeling categories ID'] in pred_ids
    # 每个类别的预测置信度
    for idx, each in enumerate(classes):
        pred_dict['{}-Predictions Confidence Level'.format(each)] = pred_softmax[0][idx].cpu().detach().numpy()
        
    df_pred = df_pred._append(pred_dict, ignore_index=True)
# Out:
# 248it [00:04, 52.06it/s]

# %%
df_pred
# Out:
#      top-1-Predictions ID top-1-Predictions name  top-2-Predictions ID  \
# 0                       0                Angular                     4
# 1                       3             Subrounded                     2
# 2                       0                Angular                     2
# 3                       0                Angular                     2
# 4                       0                Angular                     2
# ..                    ...                    ...                   ...
# 243                     3             Subrounded                     1
# 244                     5           Well rounded                     3
# 245                     2             Subangular                     3
# 246                     2             Subangular                     3
# 247                     3             Subrounded                     5
#
#     top-2-Predictions name  top-3-Predictions ID top-3-Predictions name  \
# 0             Very angular                     2             Subangular
# 1               Subangular                     0                Angular
# 2               Subangular                     4           Very angular
# 3               Subangular                     4           Very angular
# 4               Subangular                     4           Very angular
# ..                     ...                   ...                    ...
# 243                Rounded                     2             Subangular
# 244             Subrounded                     2             Subangular
# 245             Subrounded                     4           Very angular
# 246             Subrounded                     1                Rounded
# 247           Well rounded                     1                Rounded
#
#      top-n Predictions correction Angular-Predictions Confidence Level  \
# 0                            True                            0.5740181
# 1                            True                          0.020437263
# 2                            True                           0.51057106
# 3                            True                           0.42534515
# 4                            True                             0.682034
# ..                            ...                                  ...
# 243                         False                           0.03188204
# 244                          True                           0.06267947
# 245                         False                          0.037356008
# 246                         False                           0.07757834
# 247                          True                         0.0049759457
#
#     Rounded-Predictions Confidence Level  \
# 0                           0.0034985272
# 1                             0.01073399
# 2                             0.08709357
# 3                           0.0047413907
# 4                             0.01076125
# ..                                   ...
# 243                            0.3015919
# 244                            0.0921578
# 245                          0.034041755
# 246                           0.11785209
# 247                           0.17361636
#
#     Subangular-Predictions Confidence Level  \
# 0                               0.111644566
# 1                                 0.2844617
# 2                                0.16634618
# 3                                 0.4243061
# 4                                0.17730393
# ..                                      ...
# 243                              0.23369747
# 244                               0.1355485
# 245                              0.70084286
# 246                              0.44920433
# 247                              0.11572571
#
#     Subrounded-Predictions Confidence Level  \
# 0                               0.016418498
# 1                                0.67212415
# 2                                0.10468967
# 3                               0.027566545
# 4                               0.050382897
# ..                                      ...
# 243                              0.36432058
# 244                              0.27929887
# 245                              0.17599387
# 246                              0.23566626
# 247                                0.474003
#
#     Very angular-Predictions Confidence Level  \
# 0                                  0.29402992
# 1                                 0.012036975
# 2                                 0.122171775
# 3                                  0.11761896
# 4                                  0.07471112
# ..                                        ...
# 243                               0.050350558
# 244                               0.009975068
# 245                               0.043497056
# 246                               0.090628035
# 247                                0.00356481
#
#     Well rounded-Predictions Confidence Level
# 0                               0.00039027288
# 1                               0.00020592667
# 2                                 0.009127764
# 3                               0.00042182644
# 4                                 0.004806696
# ..                                        ...
# 243                               0.018157482
# 244                                 0.4203403
# 245                               0.008268428
# 246                               0.029070955
# 247                                0.22811419
#
# [248 rows x 13 columns]

# %% [markdown]
# ## 拼接AB两张表格

# %%
df = pd.concat([df, df_pred], axis=1)

# %%
df
# Out:
#                                             Image path  \
# 0    Particle Figures_split/val/Angular/Angular (10...
# 1    Particle Figures_split/val/Angular/Angular (10...
# 2    Particle Figures_split/val/Angular/Angular (11...
# 3    Particle Figures_split/val/Angular/Angular (13...
# 4    Particle Figures_split/val/Angular/Angular (13...
# ..                                                 ...
# 243  Particle Figures_split/val/Well rounded/Well r...
# 244  Particle Figures_split/val/Well rounded/Well r...
# 245  Particle Figures_split/val/Well rounded/Well r...
# 246  Particle Figures_split/val/Well rounded/Well r...
# 247  Particle Figures_split/val/Well rounded/Well r...
#
#      Labeling categories ID Labeling categories name  top-1-Predictions ID  \
# 0                         0                  Angular                     0
# 1                         0                  Angular                     3
# 2                         0                  Angular                     0
# 3                         0                  Angular                     0
# 4                         0                  Angular                     0
# ..                      ...                      ...                   ...
# 243                       5             Well rounded                     3
# 244                       5             Well rounded                     5
# 245                       5             Well rounded                     2
# 246                       5             Well rounded                     2
# 247                       5             Well rounded                     3
#
#     top-1-Predictions name  top-2-Predictions ID top-2-Predictions name  \
# 0                  Angular                     4           Very angular
# 1               Subrounded                     2             Subangular
# 2                  Angular                     2             Subangular
# 3                  Angular                     2             Subangular
# 4                  Angular                     2             Subangular
# ..                     ...                   ...                    ...
# 243             Subrounded                     1                Rounded
# 244           Well rounded                     3             Subrounded
# 245             Subangular                     3             Subrounded
# 246             Subangular                     3             Subrounded
# 247             Subrounded                     5           Well rounded
#
#      top-3-Predictions ID top-3-Predictions name  \
# 0                       2             Subangular
# 1                       0                Angular
# 2                       4           Very angular
# 3                       4           Very angular
# 4                       4           Very angular
# ..                    ...                    ...
# 243                     2             Subangular
# 244                     2             Subangular
# 245                     4           Very angular
# 246                     1                Rounded
# 247                     1                Rounded
#
#      top-n Predictions correction Angular-Predictions Confidence Level  \
# 0                            True                            0.5740181
# 1                            True                          0.020437263
# 2                            True                           0.51057106
# 3                            True                           0.42534515
# 4                            True                             0.682034
# ..                            ...                                  ...
# 243                         False                           0.03188204
# 244                          True                           0.06267947
# 245                         False                          0.037356008
# 246                         False                           0.07757834
# 247                          True                         0.0049759457
#
#     Rounded-Predictions Confidence Level  \
# 0                           0.0034985272
# 1                             0.01073399
# 2                             0.08709357
# 3                           0.0047413907
# 4                             0.01076125
# ..                                   ...
# 243                            0.3015919
# 244                            0.0921578
# 245                          0.034041755
# 246                           0.11785209
# 247                           0.17361636
#
#     Subangular-Predictions Confidence Level  \
# 0                               0.111644566
# 1                                 0.2844617
# 2                                0.16634618
# 3                                 0.4243061
# 4                                0.17730393
# ..                                      ...
# 243                              0.23369747
# 244                               0.1355485
# 245                              0.70084286
# 246                              0.44920433
# 247                              0.11572571
#
#     Subrounded-Predictions Confidence Level  \
# 0                               0.016418498
# 1                                0.67212415
# 2                                0.10468967
# 3                               0.027566545
# 4                               0.050382897
# ..                                      ...
# 243                              0.36432058
# 244                              0.27929887
# 245                              0.17599387
# 246                              0.23566626
# 247                                0.474003
#
#     Very angular-Predictions Confidence Level  \
# 0                                  0.29402992
# 1                                 0.012036975
# 2                                 0.122171775
# 3                                  0.11761896
# 4                                  0.07471112
# ..                                        ...
# 243                               0.050350558
# 244                               0.009975068
# 245                               0.043497056
# 246                               0.090628035
# 247                                0.00356481
#
#     Well rounded-Predictions Confidence Level
# 0                               0.00039027288
# 1                               0.00020592667
# 2                                 0.009127764
# 3                               0.00042182644
# 4                                 0.004806696
# ..                                        ...
# 243                               0.018157482
# 244                                 0.4203403
# 245                               0.008268428
# 246                               0.029070955
# 247                                0.22811419
#
# [248 rows x 16 columns]

# %% [markdown]
# ## 导出完整表格

# %%
df.to_csv('测试集预测结果.csv', index=False)
